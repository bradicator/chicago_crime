# %%
from utils import *

# %%
ca = CrimeAnalyzer(["./crime2022.csv", "./crime2023.csv"])
# Out:
# /Users/bradzhao/work/chicago_crime/utils.py:77: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   self.rawdf['ts'] = _pd.to_datetime(self.rawdf['ts'])

# %%
ca.select_area(41.883243, -87.627946, 500)

# %%
ca.get_report()
# Out:
# Found 5119 crimes in total for area within 500m of coordinate (-87.628, 41.883):
# ...
# Crime Count By Violence:
#  nonviolent,3931
# violent,1188
#
# Top Crime Types:
#  theft,2569
# simple_battery,555
# fraud,487
# simple_assault,279
# uncategorized,260
