# %%
from utils import *

# %%
import pandas as pd

# %%
ca = CrimeAnalyzer("./crime2022.csv")
# Out:
# /Users/bradzhao/work/chicago_crime/utils.py:77: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   self.rawdf['ts'] = _pd.to_datetime(self.rawdf['ts'])

# %%
ca.select_area(41.886785, -87.616184)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/cv/8w75k7px52v7k64zpzwz1y7r0000gn/T/ipykernel_6354/1107728942.py in ?()
# ----> 1 ca.select_area(41.886785, -87.616184)
#
# ~/work/chicago_crime/utils.py in ?(self, longitude, latitude, distance, distance_type)
#      80     def select_area(self, longitude, latitude, distance=500, distance_type="l1"):
# ---> 81         distances = get_distance(self.rawdf.longitudes, self.rawdf.latitudes, longitude, latitude, distance_type)
#      82         self.focusdf = self.rawdf.loc[distances < distance, :].copy()
#
# ~/Library/Python/3.9/lib/python/site-packages/pandas/core/generic.py in ?(self, name)
#    6200             and name not in self._accessors
#    6201             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202         ):
#    6203             return self[name]
# ...

# %%
distances = get_distance(ca.rawdf.longitude, ca.rawdf.latitude, 41.886785, -87.616184)

# %%
ca.rawdf.loc[distances < 500, :]
# Out:
#           caseid                  ts                pdesp  \
# 609     JG227435 2022-12-29 00:00:00   DECEPTIVE PRACTICE
# 751     JG104972 2022-12-30 18:10:00                THEFT
# 970     JG104338 2022-12-24 00:00:00   DECEPTIVE PRACTICE
# 1274    JG170367 2022-11-17 15:00:00   DECEPTIVE PRACTICE
# 1361    JG142077 2022-12-01 09:00:00   DECEPTIVE PRACTICE
# ...          ...                 ...                  ...
# 234931  JF513455 2022-12-16 23:23:00              BATTERY
# 235487  JF471912 2022-11-02 12:00:00   DECEPTIVE PRACTICE
# 236364  JF416878 2022-09-30 04:20:00  MOTOR VEHICLE THEFT
# 236868  JF511811 2022-12-09 00:00:00   DECEPTIVE PRACTICE
# 237533  JF436941 2022-10-16 16:17:00              BATTERY
#
#                                       sdesp        locdesp  arrest  domestic  \
# 609     FINANCIAL IDENTITY THEFT OVER $ 300      RESIDENCE   False     False
# 751                           FROM BUILDING     RESTAURANT   False     False
# ...

# %%
df = pd.read_csv("./crime2022.csv")

# %%
df2 = pd.read_csv("./crime2023.csv")

# %%
df2.columns
# Out:
# Index(['ID', 'Case Number', 'Date', 'Block', 'IUCR', 'Primary Type',
#        'Description', 'Location Description', 'Arrest', 'Domestic', 'Beat',
#        'District', 'Ward', 'Community Area', 'FBI Code', 'X Coordinate',
#        'Y Coordinate', 'Year', 'Updated On', 'Latitude', 'Longitude',
#        'Location'],
#       dtype='object')

# %%
df2.dropna()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df2.dropna()
#
# NameError: name 'df2' is not defined

# %%
pd.concat([df, df2], axis=0)
# Out:
#               ID Case Number                    Date                   Block  \
# 0       12589893    JF109865  01/11/2022 03:00:00 PM    087XX S KINGSTON AVE
# 1       12592454    JF113025  01/14/2022 03:55:00 PM       067XX S MORGAN ST
# 2       12785595    JF346553  08/05/2022 09:00:00 PM  072XX S UNIVERSITY AVE
# 3       12808281    JF373517  08/14/2022 02:00:00 PM     055XX W ARDMORE AVE
# 4       12888104    JF469015  11/10/2022 03:47:00 AM          072XX S MAY ST
# ...          ...         ...                     ...                     ...
# 223215  13047495    JG229914  04/18/2023 08:00:00 AM    003XX N JEFFERSON ST
# 223216  13168300    JG373901  08/07/2023 06:00:00 PM         0000X W 95TH ST
# 223217  13114024    JG309527  06/20/2023 07:00:00 PM       031XX S AVERS AVE
# 223218  13188860    JG398340  08/26/2023 12:00:00 AM  078XX S SOUTH SHORE DR
# 223219  13126372    JG324067  07/01/2023 07:29:00 PM        005XX S WELLS ST
#
# ...

# %%
df.query("`FBI Code` == '14' and Domestic == True")
# Out:
#               ID Case Number                    Date                    Block  \
# 298     12926661    JF515083  12/18/2022 01:00:00 PM        048XX S BISHOP ST
# 306     13253649    JG475819  10/24/2022 12:15:00 AM     006XX N TRUMBULL AVE
# 423     12899996    JF483401  11/21/2022 09:00:00 PM      045XX N KENMORE AVE
# 504     12937132    JF527704  12/30/2022 03:10:00 PM         064XX S GREEN ST
# 829     12968486    JG135355  12/25/2022 04:01:00 PM          013XX W 31ST PL
# ...          ...         ...                     ...                      ...
# 237549  12898205    JF481233  11/20/2022 04:00:00 AM        018XX N MASON AVE
# 237599  12841156    JF412842  09/26/2022 07:00:00 PM     073XX S CARPENTER ST
# 237656  12846270    JF418733  10/01/2022 12:00:00 AM         049XX W ADAMS ST
# 237780  12903688    JF487858  11/26/2022 04:45:00 AM  079XX S ST LAWRENCE AVE
# 237804  12891356    JF472674  11/13/2022 12:53:00 AM          004XX W 61ST ST
#
# ...

# %%
df.loc[df.Domestic==True,'FBI Code'].value_counts()[:50]
# Out:
# FBI Code
# 08B    19866
# 08A     5425
# 26      4738
# 14      3964
# 04B     2752
# 06      2717
# 04A     2308
# 17       631
# 02       559
# 20       479
# 05       341
# 07       335
# 11       260
# 03       193
# 15        72
# 24        61
# 01A       58
# 09        43
# 10        30
# 18        21
# Name: count, dtype: int64

# %%
df.loc[:,'Location Description'].value_counts()[:50]
# Out:
# Location Description
# STREET                                            67630
# APARTMENT                                         45595
# RESIDENCE                                         30470
# SIDEWALK                                          12056
# PARKING LOT / GARAGE (NON RESIDENTIAL)             9327
# SMALL RETAIL STORE                                 7258
# ALLEY                                              5015
# RESTAURANT                                         4863
# OTHER (SPECIFY)                                    3596
# COMMERCIAL / BUSINESS OFFICE                       3588
# DEPARTMENT STORE                                   3445
# VEHICLE NON-COMMERCIAL                             3229
# RESIDENCE - PORCH / HALLWAY                        3139
# GAS STATION                                        3066
# RESIDENCE - GARAGE                                 2772
# RESIDENCE - YARD (FRONT / BACK)                    2493
# ...

# %%
df.Domestic.value_counts()
# Out:
# Domestic
# False    194190
# True      44853
# Name: count, dtype: int64

# %%
df.iloc[0,:]
# Out:
# ID                                              12589893
# Case Number                                     JF109865
# Date                              01/11/2022 03:00:00 PM
# Block                               087XX S KINGSTON AVE
# IUCR                                                1565
# Primary Type                                 SEX OFFENSE
# Description             INDECENT SOLICITATION OF A CHILD
# Location Description                           RESIDENCE
# Arrest                                             False
# Domestic                                            True
# Beat                                                 423
# District                                               4
# Ward                                                 7.0
# Community Area                                        46
# FBI Code                                              17
# X Coordinate                                   1194660.0
# ...
